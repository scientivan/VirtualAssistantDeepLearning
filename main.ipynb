# %%
import nltk
stemmer = nltk.stem.lancaster.LancasterStemmer()

import numpy as np
import tflearn
import tensorflow
import random
import json
import pyttsx3
# Out:
# Running cells with 'Python 3.8.8 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'C:/Users/USER/AppData/Local/Programs/Python/Python38/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
with open("C:\\Users\\USER\\python Projects\\-Projects\\VirtualAssistantDeepLearning\\intents.json") as file:
    data = json.load(file)

# %%
words = []
labels = []
docs_x = []
docs_y = []

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        wrds = nltk.word_tokenize(pattern)
        words.extend(wrds)
        docs_x.append(wrds)
        docs_y.append(intent["tag"])

    if intent["tag"] not in labels:
        labels.append(intent["tag"])
words = [stemmer.stem(w.lower()) for w in words if w != "?"]
words = sorted(list(set(words)))
labels = sorted(labels)

# %%
training = []
output = []

out_empty = [0 for _ in range(len(labels))]
#docs_x [['Hi'], ['How', 'are', 'you'], ['Is', 'anyone', 'there', '?'],
#doc    ['Hi']
#       ['How', 'are', 'you']
#       ['Is', 'anyone', 'there', '?']
#       ['Hello']
#wrds   ['hi']   doc yang sudah di ambil inti kata per kata
#       ['how', 'ar', 'you']
#       ['is', 'anyon', 'ther', '?']
#words  ['buy', 'cal', 'could']
for x, doc in enumerate(docs_x):
    temporary_bag = []

    wrds = [stemmer.stem(w.lower()) for w in doc]
    print(wrds)
    for w in words:
        if w in wrds:
            temporary_bag.append(1)
        else:
            temporary_bag.append(0)
    output_row = out_empty[:]
    output_row[labels.index(docs_y[x])] = 1

    training.append(temporary_bag)
    output.append(output_row)
# Out:
# ['hi']
# ['ar', 'you', 'ther', '?']
# ['hello']
# ['good', 'day']
# ['what', 'up']
# ['yo']
# ['wassup']
# ['cya']
# ['stop']
# ['see', 'you', 'lat']
# ['goodby']
# ['good', 'bye']
# ['i', 'am', 'leav']
# ['hav', 'a', 'good', 'day']
# ['quit']
# ['exit']
# ['how', 'old']
# ['what', 'is', 'yo', 'ag']
# ['how', 'old', 'ar', 'you']
# ['ag', '?']
# ['who', 'ar', 'you']
# ['what', 'is', 'yo', 'nam']
# ['what', 'should', 'i', 'cal', 'you']
# ['what', 'yo', 'nam', '?']
# ['how', 'ar', 'you', '?']
# ['you', 'doing', 'gre', '?']
# ['how', 'is', 'yo', 'condit', '?']
# ['what', 'tim', 'is', 'it', '?']
# ['what', 'is', 'the', 'tim', '?']
# ['tel', 'me', 'the', 'tim']
# ['tim']
# ['play', 'mus']
# ['play', 'on', 'youtub']
# ['play']
# ['tel', 'me', 'a', 'jok']
# ['giv', 'me', 'a', 'jok']
# ['tel', 'me', 'someth', 'funny']
# ['brows']
# ['search', 'for']
# ['search']
# ['what', 'can', 'you', 'do', '?']
# ['how', 'can', 'you', 'help', 'me', '?']
# ['turn', 'on']
# ['what', 'lesson', 'is', 'now', '?']
# ['what', 'lesson', 'is', 'it', '?']

# %%
training = np.array(training)
output = np.array(output)
print(len(training[0])) # 46
print(len(output[0])) # 6
# Out:
# 57
# 12

# %%
net = tflearn.input_data(shape=[None,len(training[0])])
net = tflearn.fully_connected(net,8)
net = tflearn.fully_connected(net,8)
net = tflearn.fully_connected(net,len(output[0]),activation='softmax')
# Out:
# WARNING:tensorflow:From C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\tflearn\initializations.py:164: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
net = tflearn.regression(net)
model = tflearn.DNN(net)
model.fit(training,output,n_epoch=500,batch_size=8,show_metric=True)
model.save('VirtualAssistantDeepLearning\model.tflearn')

# %%
try:
    model.load('C:\\Users\\USER\\python Projects\\-Projects\\VirtualAssistantDeepLearning\\model.tflearn')
except:
    pass
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\USER\python Projects\-Projects\VirtualAssistantDeepLearning\model.tflearn

# %%
def bag_of_words(s, words):
    bag = [0 for _ in range(len(words))]

    s_words = nltk.word_tokenize(s)
    s_words = [stemmer.stem(word.lower()) for word in s_words]

    for se in s_words:
        for i, w in enumerate(words):
            if w == se:
                bag[i] = 1
            
    return np.array(bag)

intents = data['intents']
data_ = [intents[i] for i in range(len(intents))]
data_
# Out:
# [{'tag': 'greeting',
#   'patterns': ['Hi',
#    'are you there?',
#    'Hello',
#    'Good day',
#    'Whats up',
#    'Yo',
#    'Wassup'],
#   'responses': ['Hello!',
#    'Good to see you again!',
#    'Hi there, how can I help?'],
#   'context_set': ''},
#  {'tag': 'goodbye',
#   'patterns': ['cya',
#    'stop',
#    'See you later',
#    'Goodbye',
#    'Good bye',
#    'I am Leaving',
#    'Have a Good day',
#    'quit',
#    'exit'],
#   'responses': ['Sad to see you go, Sayonara ',
#    'Talk to you later',
#    'Goodbye!'],
#   'context_set': ''},
#  {'tag': 'age',
#   'patterns': ['how old', 'what is your age', 'how old are you', 'age?'],
#   'responses': ['I am 15 years old!', '15 years young!', '15'],
#   'context_set': ''},
#  {'tag': 'name',
#   'patterns': ['Who Are You',
#    'what is your name',
#    'what should I call you',
#    'whats your name?'],
#   'responses': ['You can call me Ivan.',
#    "I'm Ivan!",
#    "I'm Muhammad Scientivan."],
#   'context_set': ''},
#  {'tag': 'ask for condition',
#   'patterns': ['how are you?', 'you doing great?', 'how is your condition?'],
#   'responses': ["I'am doing so greatt!",
#    "I'm good!",
#    "I'm very nice",
#    "I'm at my best condition"],
#   'context_set': ''},
#  {'tag': 'time',
#   'patterns': ['what time is it?',
#    'what is the time?',
#    'tell me the time',
#    'time'],
#   'responses': [],
#   'context_set': ''},
#  {'tag': 'Music',
#   'patterns': ['Play Music', 'play on youtube', 'play'],
#   'responses': [],
#   'context_set': ''},
#  {'tag': 'Joke',
#   'patterns': ['Tell me a joke', 'give me a joke', 'tell me something funny'],
#   'responses': [],
#   'context_set': ''},
#  {'tag': 'Browsing',
#   'patterns': ['Browse', 'Search for', 'Search'],
#   'responses': [],
#   'context_set': ''},
#  {'tag': 'Information',
#   'patterns': ['What can you do?', 'How can you help me?'],
#   'responses': ['You can browse something, play music and others'],
#   'context_set': ''},
#  {'tag': 'Caution',
#   'patterns': ['turn on'],
#   'responses': ['Activating super brainy assistant bot!'],
#   'context_set': ''},
#  {'tag': 'Lesson',
#   'patterns': ['What lesson is now?', 'What lesson is it?'],
#   'responses': [],
#   'context_set': ''}]

# %%
import speech_recognition as sr
r = sr.Recognizer()

def takeCommand():

	r = sr.Recognizer()

	# from the speech_Recognition module
	# we will use the Microphone module
	# for listening the command
	with sr.Microphone() as source:
		print('Listening')
		
		# seconds of non-speaking audio before
		# a phrase is considered complete
		r.pause_threshold = 0.7
		audio = r.listen(source)
		
		# Now we will be using the try and catch
		# method so that if sound is recognized
		# it is good else we will have exception
		# handling
		try:
			print("Recognizing")
			
			# for Listening the command in indian
			# english we can also use 'hi-In'
			# for hindi recognizing
			Query = r.recognize_google(audio, language='en-in')
			print("the command is printed=", Query)
			
		except Exception as e:
			print(e)
			return "None"
		
		return Query

def BotSpeak(audio):
	
    	
	engine = pyttsx3.init()
	# getter method(gets the current value
	# of engine property)
	voices = engine.getProperty('voices')
	
	# setter method .[0]=male voice and
	# [1]=female voice in set Property.
	engine.setProperty('voice', voices[0].id)
	engine.setProperty('rate',185)
	# Method for the speaking of the the assistant
	engine.say(audio)
	
	# Blocks while processing all the currently
	# queued commands
	engine.runAndWait()

# %%
import pywhatkit
import datetime

def PlayMusic(song):
    pywhatkit.playonyt(song)
    BotSpeak('Playing' + song)

def TellTime():
    time = str(datetime.datetime.now())
    print(time) #2021-08-06 15:45:35.522024
    hour = time[11:13]
    min = time[14:16]
    sec = time[17:19]
    BotSpeak("It's " + hour + "Hours" + min + "Minutes and" + sec + 'Seconds')	
    
def SearchOnGoogle(searchInput_):
    if 'search' in searchInput_:
        searchInput_ = searchInput_.replace('search','')
    if 'for' in searchInput_:
        searchInput_ = searchInput_.replace('for','')
    if 'browse' in searchInput_:
        search = searchInput_.replace('browse','')
    search = search.lower()
    BotSpeak('Searching for ' +search)
    pywhatkit.search(search)

def TellDay():
	day = datetime.datetime.today().weekday() + 1
	
	Day_dict = {1: 'Monday', 2: 'Tuesday',
				3: 'Wednesday', 4: 'Thursday',
				5: 'Friday', 6: 'Saturday',
				7: 'Sunday'}
	
	if day in Day_dict.keys():
		day_of_the_week = Day_dict[day]
		return day_of_the_week
    
def SchoolSchedule():
    day = TellDay()
    if day.lower() != 'sunday' and day.lower() != 'saturday':
        time = str(datetime.datetime.now())
        #print(time) #2021-08-06 15:45:35.522024
        hour = int(time[11:13])
        min = int(time[14:16])
        time = (hour * 60) + min
        if day.lower() == 'monday':
            if time > 435 and time < 480:
                return 'Compulsory English Lesson'
            elif time > 525 and time < 630:
                return 'Religion Lesson'
            elif time > 630 and time < 720:
                return 'Specialization English Lesson'
            elif time > 750 and time < 840:
                return 'Specialization Mathematic Lesson'
        elif day.lower() == 'tuesday':
            if time > 435 and time < 480:
                return 'Civil lesson'
            elif time > 525 and time < 630:
                return 'Chemistry lesson'
            elif time > 630 and time < 720:
                return 'Indonesia lesson'
        elif day.lower() == 'wednesday':
            if time > 435 and time < 480:
                return 'Compulsory Mathematic lesson'
            elif time > 525 and time < 630:
                return 'Art and culture lesson'
            elif time > 630 and time < 720:
                return 'Crafts lesson'
        elif day.lower() == 'thursday':
            if time > 435 and time < 480:
                return 'Javanese lesson'
            elif time > 525 and time < 630:
                return 'Sport lesson'
            elif time > 630 and time < 720:
                return 'Physics lesson'
        elif day.lower() == 'friday':
            if time > 435 and time < 480:
                return 'Japanese lesson'
            elif time > 525 and time < 630:
                return 'Biology lesson'
            elif time > 630 and time < 720:
                return 'Indonesian Historic lesson'

# %%
import pyjokes

def TakeInput():
    inp = takeCommand().lower()
    return inp 

def GiveOutput(input_):
    results = model.predict([bag_of_words(input_, words)])
    result_index_ = np.argmax(results)  
    print('CATEGORY: ', labels[result_index_])
    return result_index_

def GiveResponses(result_index__,input_):
    for i in range(len(data_)):
        if labels[result_index__] == data_[i]['tag']:
            choice = ''
            if data_[5] == data_[i]: # Time condition
                TellTime()
            elif data_[6] == data_[i]:
                command = str.replace(input_.lower(),'play','')
                PlayMusic(command)
            elif data_[7] == data_[i]: 
                BotSpeak(pyjokes.get_joke())
            elif data_[8] == data_[i]: 
                SearchOnGoogle(input_.lower())
            elif data_[11] == data_[i]:
                BotSpeak('It is time for' + SchoolSchedule())
            else:
                choice = data_[i]['responses'][random.randint(0,len(data_[i]['responses'] ) - 1)]
                BotSpeak(choice)

# %%
def UserSpeak():
    condition = False
    while True:
        inp = TakeInput()
        if 'turn on' in inp.lower():
            condition = True
        elif 'turn off' in inp.lower():
            condition = False
        if condition == True:          
            result_index = GiveOutput(inp)
            print(result_index)

            if labels[result_index] == data_[1]['tag']: # goodbye condition
                BotSpeak(data_[1]['responses'][random.randint(0,len(data_[1]['responses'] ) - 1)])
                break

            GiveResponses(result_index,inp)
UserSpeak()
# Out:
# Listening
# Recognizing
#
# Listening
# Recognizing
# the command is printed= turn on turn on
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-28d5479658f5> in <module>
#      16
#      17             GiveResponses(result_index,inp)
# ---> 18 UserSpeak()
#
# <ipython-input-13-28d5479658f5> in UserSpeak()
#       8             condition = False
#       9         if condition == True:
# ---> 10             result_index = GiveOutput(inp)
#      11             print(result_index)
#      12
#
# <ipython-input-12-024cf253638d> in GiveOutput(input_)
#       6
#       7 def GiveOutput(input_):
# ----> 8     results = model.predict([bag_of_words(input_, words)])
#       9     result_index_ = np.argmax(results)
#      10     print('CATEGORY: ', labels[result_index_])
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tflearn\models\dnn.py in predict(self, X)
#     249         """
#     250         feed_dict = feed_dict_builder(X, None, self.inputs, None)
# --> 251         return self.predictor.predict(feed_dict)
#     252
#     253     def predict_label(self, X):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tflearn\helpers\evaluator.py in predict(self, feed_dict)
#      64
#      65             # Prediction for each tensor
# ---> 66             tflearn.is_training(False, self.session)
#      67             prediction = []
#      68             if len(self.tensors) == 1:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tflearn\config.py in is_training(is_training, session)
#      95         tf.get_collection('is_training_ops')[0].eval(session=session)
#      96     else:
# ---> 97         tf.get_collection('is_training_ops')[1].eval(session=session)
#      98
#      99
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\framework\ops.py in eval(self, feed_dict, session)
#     934       A numpy array corresponding to the value of this tensor.
#     935     """
# --> 936     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     937
#     938   @deprecation.deprecated(None, "Use ref() instead.")
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\framework\ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5541                        "the tensor's graph is different from the session's "
#    5542                        "graph.")
# -> 5543   return session.run(tensors, feed_dict)
#    5544
#    5545
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1112     # Check session.
#    1113     if self._closed:
# -> 1114       raise RuntimeError('Attempted to use a closed Session.')
#    1115     if self.graph.version == 0:
#    1116       raise RuntimeError('The Session graph is empty.  Add operations to the '
#
# RuntimeError: Attempted to use a closed Session.
