# %%
import pandas as pd
import pywhatkit

# %%
df = pd.read_excel("whatsapp.xlsx")

# %%
df.Phone
# Out:
# 0      6281391454045
# 1      6281391454045
# 2      6281808115444
# 3      6288221569566
# 4      6285741130459
#            ...
# 235    6285974758267
# 236    6281392823485
# 237    6287891514457
# 238    6289616238811
# 239    6285328840507
# Name: Phone, Length: 240, dtype: int64

# %%
len(df.Phone)
# Out:
# 240

# %%
with open('bc.txt') as file:
    data = file.read()
print(data)#prints out the file
type(data)
# Out:
# HALO, SOON TO BE PADMANABA
#
# Sekarang kamu sudah terdaftar sebagai peserta Try Out Superman nih, terimakasih ya! Nah biar enggak ketinggalan informasi apapun, kamu bisa join group Telegram sesuai hari try out lewat link di bawah ya!
#
# DAY 1
# https://t.me/+7Kcjds8FGjcxYmI1
#
# DAY 2
# https://t.me/+QTLzpBs4b49lNjg1
#
# Jangan lupa juga post foto kalian yang cantik ganteng itu di Instagram pakai Twibbon PSW !
# LINK TWIBBON
# https://twb.nz/tryoutsuperman-psw
# Kenapa harus pakai twibbon kaak? KARENAAA kita juga ada hadiah nihh buat teman-teman yang sudah post twibbon dan beruntung!
#
# 5 Voucher Kakkoi senilai Rp1.000.000,00
# 5 Tiket Try Out Superman GRATIS
#
# Banyaaakk banget kaan hadiahnyaa? Jadi jangan lupa join grup telegram dan pakaiÂ twibbonnyaÂ yaa!
# str

# %%
# pywhatkit.sendwhatmsg("+6282137609530",message=data,time_hour=00,time_min=5)
# Out:
# In 18 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!

# %%
phone_number = []
for i in df.Phone:
    i = str(i)
    i = "+" + i
    pywhatkit.sendwhatmsg(i,message=data,time_hour=00,time_min=7)
    phone_number.append(i)
# Out:
# In 28 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
# In 86384 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!

# %%
phone_number
# Out:
# ['+6281391454045',
#  '+6281391454045',
#  '+6281808115444',
#  '+6288221569566',
#  '+6285741130459',
#  '+62895335233808',
#  '+628979749371',
#  '+6281226097184',
#  '+6285799728818',
#  '+6281393964711',
#  '+6289612650481',
#  '+62882005820456',
#  '+6289637833702',
#  '+6289527121355',
#  '+6282259244585',
#  '+6289504854405',
#  '+6285894296058',
#  '+6287739167878',
#  '+6285643201737',
#  '+62882003698400',
#  '+6281578777290',
#  '+628806612020',
#  '+628157997835',
#  '+6281228484608',
#  '+6283187756144',
#  '+6287705391755',
#  '+6289517687456',
#  '+6282241832680',
#  '+6282134614844',
#  '+62895392251722',
#  '+6281215827818',
#  '+6288239325383',
#  '+6289602399990',
#  '+6289618522764',
#  '+628112636361',
#  '+628812871724',
#  '+6288238423266',
#  '+62895406013377',
#  '+6287772327210',
#  '+62895423047631',
#  '+6281327006000',
#  '+628993817041',
#  '+62895417673600',
#  '+6281227424177',
#  '+6281325460876',
#  '+6289657686090',
#  '+6281314218274',
# ...

# %%
phone_number[0]
# Out:
# 6281391454045
